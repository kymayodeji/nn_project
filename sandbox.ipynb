# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
path = "data\IMG_1342.JPEG"
image = Image.open(path).convert('RGB')
image=np.asarray(image)

# %%
len(image)
# Out:
# 3088

# %%
image.shape
# Out:
# (3088, 2316, 3)

# %%
plt.figure(figsize=(12,4))
plt.imshow(image.astype(int))
#plt.axis("off")

# %%
image2= cv2.imread(path)

# %%
width, height = 224, 224
resized_image2 = cv2.resize(image2, (width, height))

# %%
plt.figure(figsize=(12,4))
plt.imshow(resized_image2.astype(int))
#plt.axis("off")

# %%
normalized_image = resized_image2/255.0
plt.figure(figsize=(12,4))
plt.imshow(normalized_image.astype(int))
#plt.axis("off")

# %%
data_folder = "C:\Users\kymno\Pictures\data"
data = tf.keras.utils.image_dataset_from_directory(data_folder)
# Out:
# Object `tf.data.Dataset` not found.

# %%
img3 = cv2.imread(path)
annotation = cv2.rectangle(img3, (0, 0), (2500, 2000), (0, 255, 0), 0)
cv2.imwrite('labeled_img.jpg')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[27], line 3
#       1 img3 = cv2.imread(path)
#       2 annotation = cv2.rectangle(img3, (0, 0), (2500, 2000), (0, 255, 0), 0)
# ----> 3 cv2.imwrite('labeled_img.jpg')
#
# error: OpenCV(4.8.1) :-1: error: (-5:Bad argument) in function 'imwrite'
# > Overload resolution failed:
# >  - imwrite() missing required argument 'img' (pos 2)
# >  - imwrite() missing required argument 'img' (pos 2)
